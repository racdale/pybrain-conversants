# %%
trials = 5000
szIn = 5
hids = 50
LR = .15

execfile('loadLibraries.py')
execfile('buildChangNet.py')
execfile('buildTurnInput.py')

# %matplotlib inline
plt.plot(np.array(preds)[(len(preds)-20):len(preds),0])

# %%
x = np.array(preds)[(len(preds)-20):len(preds),0]
x[:,0:5]
# Out:
# array([[ 0.55513326,  0.99980019,  0.0064674 ,  0.00873306],
#        [ 0.4433407 ,  0.99979749,  0.00654168,  0.00882761],
#        [ 0.0152265 ,  0.99989129,  0.54414216,  0.46031217],
#        [ 0.01501634,  0.99988839,  0.45538351,  0.53914309],
#        [ 0.55512768,  0.99979992,  0.00646509,  0.00873046],
#        [ 0.44334655,  0.99979722,  0.00653934,  0.00882498],
#        [ 0.01522634,  0.99989112,  0.54413484,  0.46031858],
#        [ 0.01501625,  0.99988823,  0.45539056,  0.53913725],
#        [ 0.5551221 ,  0.99979965,  0.00646278,  0.00872786],
#        [ 0.4433524 ,  0.99979695,  0.006537  ,  0.00882235],
#        [ 0.01522619,  0.99989096,  0.54412753,  0.460325  ],
#        [ 0.01501617,  0.99988806,  0.4553976 ,  0.53913141],
#        [ 0.55511652,  0.99979938,  0.00646048,  0.00872526],
#        [ 0.44335825,  0.99979668,  0.00653467,  0.00881972],
#        [ 0.01522604,  0.9998908 ,  0.54412022,  0.46033141],
# ...

# %%
net_a_p.offset
# Out:
# 1

# %%
plt.plot(np.array(preds)[(len(preds)-20):(len(preds)-1),0][:,0:4])

# %%
len(ds)
# Out:
# 1

# %%
ds

# %%
ds['input']
# Out:
# array([[ 0.00975866,  0.00403373,  0.0045012 ,  0.99191556]])

# %%
np.array(preds)[3000:3010,3]
# Out:
# array([ 0.00714253,  0.00670018,  0.00735858,  0.98497516,  0.00712145,
#         0.00668038,  0.00733699,  0.98502399,  0.00710049,  0.00666067])

# %%
dir(net_a_p['hidden input from comp'])
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__doc__',
#  '__format__',
#  '__getattribute__',
#  '__hash__',
#  '__init__',
#  '__module__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_backwardImplementation',
#  '_forwardImplementation',
#  '_generateName',
#  '_getName',
#  '_growBuffers',
#  '_name',
#  '_nameIds',
#  '_resetBuffers',
#  '_setName',
#  'activate',
#  'activateOnDataset',
#  'argdict',
#  'backActivate',
#  'backward',
#  'bufferlist',
#  'dim',
#  'forward',
#  'getName',
#  'indim',
#  'inputbuffer',
#  'inputerror',
#  'name',
#  'offset',
#  'outdim',
#  'outputbuffer',
#  'outputerror',
#  'paramdim',
#  'reset',
#  'sequential',
#  'setArgs',
#  'setName',
#  'shift',
#  'whichNeuron']

# %%
net_a_p['hidden input from comp'].inputbuffer
# Out:
# array([[ 0.,  0.],
#        [ 0.,  0.]])

# %%
meaning[0]
# Out:
# [1, 1, 1, 0]
